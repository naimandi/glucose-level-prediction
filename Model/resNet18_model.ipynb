# %%
import os
import shutil
import glob
import numpy as np
import pandas as pd

# %%
from torchvision.datasets import DatasetFolder
from PIL import Image
from torchvision import transforms
import torch
import pandas as pd

class GlucoseDataset(DatasetFolder):
    def __init__(self, img_dir, dataframe, transform=None):
        self.img_dir = img_dir
        self.transform = transform
        self.dataframe = dataframe

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = self.dataframe.iloc[idx, 0]
        glucose_level = self.dataframe.iloc[idx, 1]
        image = Image.open(img_path).convert('RGB')  # Convert grayscale images to RGB
        if self.transform:
            image = self.transform(image)
        return image, glucose_level

data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
}

# %%
data_dir = "/glucose-prediction/RP_Images/"


train_df = pd.read_csv('/Users/nadia/Work/College_Courses/ImmersiveScholar2023/glucose-prediction/Mappings/train_mappings.csv')
val_df = pd.read_csv('/Users/nadia/Work/College_Courses/ImmersiveScholar2023/glucose-prediction/Mappings/val_mappings.csv')


train_dataset = GlucoseDataset(data_dir + 'train', train_df, transform=data_transforms['train'])
val_dataset = GlucoseDataset(data_dir + 'val', val_df, transform=data_transforms['val'])

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=64, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from torch.optim.lr_scheduler import StepLR
from torchvision.models import resnet18
from torchvision.models.resnet import ResNet18_Weights

best_model_path = 'best_model_accuracy.pth'

model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)

# Adjust the model's fully connected layer for regression
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 1)

# Loss functions
def rmse(y_true, y_pred):
    return torch.sqrt(torch.mean((y_pred - y_true) ** 2))

def mape(y_true, y_pred):
    return torch.mean(torch.abs((y_true - y_pred) / (y_true + 1e-8)))

# custom 
def combined_loss(y_true, y_pred):
    return rmse(y_true, y_pred) + mape(y_true, y_pred)

# Added function to compute accuracy from MAPE
def accuracy_from_mape(mape_val):
    return 100 - (mape_val*100)

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.8)
scheduler = StepLR(optimizer, step_size=10, gamma=0.1)
num_epochs = 200

best_train_rmse, best_val_rmse = float('inf'), float('inf')
best_train_mape, best_val_mape = float('inf'), float('inf')
best_train_loss, best_val_loss = float('inf'), float('inf')
best_train_accuracy, best_val_accuracy = 0.0, 0.0

# training loop
for epoch in range(num_epochs):
    model.train()
    total_loss, total_rmse, total_mape = 0.0, 0.0, 0.0

    for images, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = combined_loss(labels, outputs)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * images.size(0)
        total_rmse += rmse(labels, outputs).item() * images.size(0)
        total_mape += mape(labels, outputs).item() * images.size(0)

    avg_train_loss = total_loss / len(train_dataset)
    avg_train_rmse = total_rmse / len(train_dataset)
    avg_train_mape = total_mape / len(train_dataset)
    train_accuracy = accuracy_from_mape(avg_train_mape)

    if avg_train_loss < best_train_loss:
        best_train_loss = avg_train_loss
    if avg_train_rmse < best_train_rmse:
        best_train_rmse = avg_train_rmse
    if avg_train_mape < best_train_mape:
        best_train_mape = avg_train_mape
    if train_accuracy > best_train_accuracy:
        best_train_accuracy = train_accuracy
   
    


    print(f'Epoch [{epoch+1}/{num_epochs}]')
    print("-" * 10)
    print(f'Train Loss: {avg_train_loss:.4f}, RMSE: {avg_train_rmse:.4f}, MAPE: {avg_train_mape:.4f}, Accuracy: {train_accuracy:.2f}%')

    model.eval()
    total_val_loss, total_val_rmse, total_val_mape = 0.0, 0.0, 0.0
    with torch.no_grad():
        for images, labels in val_loader:
            outputs = model(images)
            total_val_loss += combined_loss(labels, outputs).item() * images.size(0)
            total_val_rmse += rmse(labels, outputs).item() * images.size(0)
            total_val_mape += mape(labels, outputs).item() * images.size(0)

        avg_val_loss = total_val_loss / len(val_dataset)
        avg_val_rmse = total_val_rmse / len(val_dataset)
        avg_val_mape = total_val_mape / len(val_dataset)
        val_accuracy = accuracy_from_mape(avg_val_mape)

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
        if avg_val_rmse < best_val_rmse:
            best_val_rmse = avg_val_rmse
        if avg_val_mape < best_val_mape:
            best_val_mape = avg_val_mape
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            torch.save(model.state_dict(), best_model_path)


    print(f'Val Loss: {avg_val_loss:.4f}, RMSE: {avg_val_rmse:.4f}, MAPE: {avg_val_mape:.4f}, Accuracy: {val_accuracy:.2f}%')
    scheduler.step()

print(f'Best Train Loss: {best_train_loss:.4f}, Best Train RMSE: {best_train_rmse:.4f}, Best Train MAPE: {best_train_mape:.4f}, Best Train Accuracy: {best_train_accuracy:.2f}%')
print(f'Best Val Loss: {best_val_loss:.4f}, Best Val RMSE: {best_val_rmse:.4f}, Best Val MAPE: {best_val_mape:.4f}, Best Val Accuracy: {best_val_accuracy:.2f}%')
# Out:
# Epoch [1/200]
# ----------
# Train Loss: 47.0750, RMSE: 46.7031, MAPE: 0.3719, Accuracy: 62.81%
# Val Loss: 20.5694, RMSE: 20.4095, MAPE: 0.1599, Accuracy: 84.01%
# Epoch [2/200]
# ----------
# Train Loss: 21.8673, RMSE: 21.7150, MAPE: 0.1523, Accuracy: 84.77%
# Val Loss: 18.4934, RMSE: 18.3687, MAPE: 0.1247, Accuracy: 87.53%
# Epoch [3/200]
# ----------
# Train Loss: 21.7432, RMSE: 21.5923, MAPE: 0.1509, Accuracy: 84.91%
# Val Loss: 18.3069, RMSE: 18.1798, MAPE: 0.1271, Accuracy: 87.29%
# Epoch [4/200]
# ----------
# Train Loss: 21.8177, RMSE: 21.6677, MAPE: 0.1500, Accuracy: 85.00%
# Val Loss: 18.3219, RMSE: 18.1916, MAPE: 0.1304, Accuracy: 86.96%
# Epoch [5/200]
# ----------
# Train Loss: 21.7189, RMSE: 21.5692, MAPE: 0.1496, Accuracy: 85.04%
# Val Loss: 18.5512, RMSE: 18.4149, MAPE: 0.1362, Accuracy: 86.38%
# Epoch [6/200]
# ----------
# Train Loss: 21.6701, RMSE: 21.5192, MAPE: 0.1508, Accuracy: 84.92%
# Val Loss: 18.2922, RMSE: 18.1641, MAPE: 0.1282, Accuracy: 87.18%
# Epoch [7/200]
# ----------
# Train Loss: 21.9364, RMSE: 21.7861, MAPE: 0.1503, Accuracy: 84.97%
# Val Loss: 18.3479, RMSE: 18.2163, MAPE: 0.1316, Accuracy: 86.84%
# Epoch [8/200]
# ----------
# Train Loss: 21.6654, RMSE: 21.5163, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 19.7904, RMSE: 19.6356, MAPE: 0.1548, Accuracy: 84.52%
# Epoch [9/200]
# ----------
# Train Loss: 22.0801, RMSE: 21.9244, MAPE: 0.1557, Accuracy: 84.43%
# Val Loss: 18.2943, RMSE: 18.1661, MAPE: 0.1282, Accuracy: 87.18%
# Epoch [10/200]
# ----------
# Train Loss: 21.6047, RMSE: 21.4549, MAPE: 0.1498, Accuracy: 85.02%
# Val Loss: 18.3627, RMSE: 18.2372, MAPE: 0.1256, Accuracy: 87.44%
# Epoch [11/200]
# ----------
# Train Loss: 21.5621, RMSE: 21.4140, MAPE: 0.1481, Accuracy: 85.19%
# Val Loss: 18.3114, RMSE: 18.1813, MAPE: 0.1300, Accuracy: 87.00%
# Epoch [12/200]
# ----------
# Train Loss: 21.5496, RMSE: 21.3994, MAPE: 0.1502, Accuracy: 84.98%
# Val Loss: 18.2958, RMSE: 18.1675, MAPE: 0.1283, Accuracy: 87.17%
# Epoch [13/200]
# ----------
# Train Loss: 21.5939, RMSE: 21.4457, MAPE: 0.1482, Accuracy: 85.18%
# Val Loss: 18.2971, RMSE: 18.1692, MAPE: 0.1279, Accuracy: 87.21%
# Epoch [14/200]
# ----------
# Train Loss: 21.5881, RMSE: 21.4398, MAPE: 0.1483, Accuracy: 85.17%
# Val Loss: 18.3003, RMSE: 18.1710, MAPE: 0.1293, Accuracy: 87.07%
# Epoch [15/200]
# ----------
# Train Loss: 21.5773, RMSE: 21.4282, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.3056, RMSE: 18.1758, MAPE: 0.1297, Accuracy: 87.03%
# Epoch [16/200]
# ----------
# Train Loss: 21.5608, RMSE: 21.4098, MAPE: 0.1511, Accuracy: 84.89%
# Val Loss: 18.2998, RMSE: 18.1722, MAPE: 0.1276, Accuracy: 87.24%
# Epoch [17/200]
# ----------
# Train Loss: 21.6042, RMSE: 21.4552, MAPE: 0.1490, Accuracy: 85.10%
# Val Loss: 18.3090, RMSE: 18.1792, MAPE: 0.1299, Accuracy: 87.01%
# Epoch [18/200]
# ----------
# Train Loss: 21.5677, RMSE: 21.4167, MAPE: 0.1510, Accuracy: 84.90%
# Val Loss: 18.3094, RMSE: 18.1824, MAPE: 0.1271, Accuracy: 87.29%
# Epoch [19/200]
# ----------
# Train Loss: 21.6377, RMSE: 21.4903, MAPE: 0.1474, Accuracy: 85.26%
# Val Loss: 18.3043, RMSE: 18.1770, MAPE: 0.1273, Accuracy: 87.27%
# Epoch [20/200]
# ----------
# Train Loss: 21.5467, RMSE: 21.4002, MAPE: 0.1465, Accuracy: 85.35%
# Val Loss: 18.2967, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [21/200]
# ----------
# Train Loss: 21.5895, RMSE: 21.4399, MAPE: 0.1497, Accuracy: 85.03%
# Val Loss: 18.3010, RMSE: 18.1716, MAPE: 0.1294, Accuracy: 87.06%
# Epoch [22/200]
# ----------
# Train Loss: 21.5204, RMSE: 21.3707, MAPE: 0.1498, Accuracy: 85.02%
# Val Loss: 18.3037, RMSE: 18.1741, MAPE: 0.1296, Accuracy: 87.04%
# Epoch [23/200]
# ----------
# Train Loss: 21.5894, RMSE: 21.4395, MAPE: 0.1499, Accuracy: 85.01%
# Val Loss: 18.3042, RMSE: 18.1746, MAPE: 0.1296, Accuracy: 87.04%
# Epoch [24/200]
# ----------
# Train Loss: 21.5855, RMSE: 21.4357, MAPE: 0.1498, Accuracy: 85.02%
# Val Loss: 18.3021, RMSE: 18.1726, MAPE: 0.1295, Accuracy: 87.05%
# Epoch [25/200]
# ----------
# Train Loss: 21.5574, RMSE: 21.4077, MAPE: 0.1497, Accuracy: 85.03%
# Val Loss: 18.3005, RMSE: 18.1711, MAPE: 0.1293, Accuracy: 87.07%
# Epoch [26/200]
# ----------
# Train Loss: 21.6092, RMSE: 21.4599, MAPE: 0.1493, Accuracy: 85.07%
# Val Loss: 18.2983, RMSE: 18.1692, MAPE: 0.1291, Accuracy: 87.09%
# Epoch [27/200]
# ----------
# Train Loss: 21.5637, RMSE: 21.4139, MAPE: 0.1498, Accuracy: 85.02%
# Val Loss: 18.2996, RMSE: 18.1703, MAPE: 0.1293, Accuracy: 87.07%
# Epoch [28/200]
# ----------
# Train Loss: 21.5864, RMSE: 21.4368, MAPE: 0.1497, Accuracy: 85.03%
# Val Loss: 18.2999, RMSE: 18.1706, MAPE: 0.1293, Accuracy: 87.07%
# Epoch [29/200]
# ----------
# Train Loss: 21.5323, RMSE: 21.3828, MAPE: 0.1495, Accuracy: 85.05%
# Val Loss: 18.2993, RMSE: 18.1700, MAPE: 0.1293, Accuracy: 87.07%
# Epoch [30/200]
# ----------
# Train Loss: 21.6143, RMSE: 21.4650, MAPE: 0.1493, Accuracy: 85.07%
# Val Loss: 18.2966, RMSE: 18.1676, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [31/200]
# ----------
# Train Loss: 21.6210, RMSE: 21.4718, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2977, RMSE: 18.1686, MAPE: 0.1291, Accuracy: 87.09%
# Epoch [32/200]
# ----------
# Train Loss: 21.5821, RMSE: 21.4329, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2972, RMSE: 18.1682, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [33/200]
# ----------
# Train Loss: 21.4902, RMSE: 21.3410, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2964, RMSE: 18.1674, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [34/200]
# ----------
# Train Loss: 21.4930, RMSE: 21.3439, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2977, RMSE: 18.1687, MAPE: 0.1291, Accuracy: 87.09%
# Epoch [35/200]
# ----------
# Train Loss: 21.5481, RMSE: 21.3990, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1676, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [36/200]
# ----------
# Train Loss: 21.5765, RMSE: 21.4274, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [37/200]
# ----------
# Train Loss: 21.5759, RMSE: 21.4268, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2964, RMSE: 18.1675, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [38/200]
# ----------
# Train Loss: 21.6110, RMSE: 21.4619, MAPE: 0.1490, Accuracy: 85.10%
# Val Loss: 18.2967, RMSE: 18.1679, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [39/200]
# ----------
# Train Loss: 21.5850, RMSE: 21.4359, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2967, RMSE: 18.1678, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [40/200]
# ----------
# Train Loss: 21.5482, RMSE: 21.3991, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2972, RMSE: 18.1683, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [41/200]
# ----------
# Train Loss: 21.6036, RMSE: 21.4545, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2969, RMSE: 18.1679, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [42/200]
# ----------
# Train Loss: 21.5814, RMSE: 21.4322, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2981, RMSE: 18.1691, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [43/200]
# ----------
# Train Loss: 21.5218, RMSE: 21.3727, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2972, RMSE: 18.1682, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [44/200]
# ----------
# Train Loss: 21.5846, RMSE: 21.4355, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2957, RMSE: 18.1669, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [45/200]
# ----------
# Train Loss: 21.5644, RMSE: 21.4153, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1673, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [46/200]
# ----------
# Train Loss: 21.6203, RMSE: 21.4712, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2969, RMSE: 18.1679, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [47/200]
# ----------
# Train Loss: 21.5050, RMSE: 21.3560, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2971, RMSE: 18.1682, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [48/200]
# ----------
# Train Loss: 21.5111, RMSE: 21.3620, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2957, RMSE: 18.1669, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [49/200]
# ----------
# Train Loss: 21.5499, RMSE: 21.4008, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2976, RMSE: 18.1686, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [50/200]
# ----------
# Train Loss: 21.5765, RMSE: 21.4274, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1675, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [51/200]
# ----------
# Train Loss: 21.5825, RMSE: 21.4334, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2969, RMSE: 18.1679, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [52/200]
# ----------
# Train Loss: 21.5570, RMSE: 21.4079, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2973, RMSE: 18.1683, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [53/200]
# ----------
# Train Loss: 21.5987, RMSE: 21.4495, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2970, RMSE: 18.1680, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [54/200]
# ----------
# Train Loss: 21.5525, RMSE: 21.4034, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2977, RMSE: 18.1686, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [55/200]
# ----------
# Train Loss: 21.5756, RMSE: 21.4264, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [56/200]
# ----------
# Train Loss: 21.5769, RMSE: 21.4278, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2957, RMSE: 18.1669, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [57/200]
# ----------
# Train Loss: 21.5258, RMSE: 21.3767, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [58/200]
# ----------
# Train Loss: 21.5439, RMSE: 21.3948, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2972, RMSE: 18.1682, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [59/200]
# ----------
# Train Loss: 21.5519, RMSE: 21.4028, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1674, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [60/200]
# ----------
# Train Loss: 21.5177, RMSE: 21.3686, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2971, RMSE: 18.1680, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [61/200]
# ----------
# Train Loss: 21.5163, RMSE: 21.3672, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1673, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [62/200]
# ----------
# Train Loss: 21.6114, RMSE: 21.4623, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2968, RMSE: 18.1678, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [63/200]
# ----------
# Train Loss: 21.5683, RMSE: 21.4192, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2953, RMSE: 18.1665, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [64/200]
# ----------
# Train Loss: 21.5201, RMSE: 21.3710, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2974, RMSE: 18.1685, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [65/200]
# ----------
# Train Loss: 21.5277, RMSE: 21.3786, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1675, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [66/200]
# ----------
# Train Loss: 21.5254, RMSE: 21.3763, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2970, RMSE: 18.1680, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [67/200]
# ----------
# Train Loss: 21.5664, RMSE: 21.4173, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2972, RMSE: 18.1682, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [68/200]
# ----------
# Train Loss: 21.5707, RMSE: 21.4215, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2975, RMSE: 18.1685, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [69/200]
# ----------
# Train Loss: 21.6119, RMSE: 21.4629, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2960, RMSE: 18.1671, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [70/200]
# ----------
# Train Loss: 21.5418, RMSE: 21.3926, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2960, RMSE: 18.1671, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [71/200]
# ----------
# Train Loss: 21.5813, RMSE: 21.4322, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2954, RMSE: 18.1666, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [72/200]
# ----------
# Train Loss: 21.5447, RMSE: 21.3955, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2972, RMSE: 18.1682, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [73/200]
# ----------
# Train Loss: 21.5856, RMSE: 21.4365, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2978, RMSE: 18.1688, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [74/200]
# ----------
# Train Loss: 21.6254, RMSE: 21.4763, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2962, RMSE: 18.1673, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [75/200]
# ----------
# Train Loss: 21.6066, RMSE: 21.4575, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2970, RMSE: 18.1681, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [76/200]
# ----------
# Train Loss: 21.5848, RMSE: 21.4357, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2969, RMSE: 18.1680, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [77/200]
# ----------
# Train Loss: 21.5816, RMSE: 21.4325, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2962, RMSE: 18.1672, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [78/200]
# ----------
# Train Loss: 21.5403, RMSE: 21.3912, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2974, RMSE: 18.1685, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [79/200]
# ----------
# Train Loss: 21.5061, RMSE: 21.3569, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2970, RMSE: 18.1680, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [80/200]
# ----------
# Train Loss: 21.5494, RMSE: 21.4003, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2968, RMSE: 18.1678, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [81/200]
# ----------
# Train Loss: 21.5324, RMSE: 21.3833, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2952, RMSE: 18.1665, MAPE: 0.1287, Accuracy: 87.13%
# Epoch [82/200]
# ----------
# Train Loss: 21.6119, RMSE: 21.4628, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [83/200]
# ----------
# Train Loss: 21.5900, RMSE: 21.4409, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [84/200]
# ----------
# Train Loss: 21.5534, RMSE: 21.4043, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2958, RMSE: 18.1669, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [85/200]
# ----------
# Train Loss: 21.5222, RMSE: 21.3731, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1675, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [86/200]
# ----------
# Train Loss: 21.5655, RMSE: 21.4164, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2968, RMSE: 18.1679, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [87/200]
# ----------
# Train Loss: 21.5629, RMSE: 21.4138, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [88/200]
# ----------
# Train Loss: 21.5508, RMSE: 21.4017, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2972, RMSE: 18.1682, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [89/200]
# ----------
# Train Loss: 21.5460, RMSE: 21.3968, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2976, RMSE: 18.1686, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [90/200]
# ----------
# Train Loss: 21.6197, RMSE: 21.4706, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2958, RMSE: 18.1670, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [91/200]
# ----------
# Train Loss: 21.5911, RMSE: 21.4420, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [92/200]
# ----------
# Train Loss: 21.6163, RMSE: 21.4672, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2968, RMSE: 18.1678, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [93/200]
# ----------
# Train Loss: 21.5971, RMSE: 21.4480, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [94/200]
# ----------
# Train Loss: 21.6202, RMSE: 21.4710, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2981, RMSE: 18.1691, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [95/200]
# ----------
# Train Loss: 21.4989, RMSE: 21.3498, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2974, RMSE: 18.1684, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [96/200]
# ----------
# Train Loss: 21.5800, RMSE: 21.4308, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2971, RMSE: 18.1682, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [97/200]
# ----------
# Train Loss: 21.6056, RMSE: 21.4565, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [98/200]
# ----------
# Train Loss: 21.5911, RMSE: 21.4420, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2962, RMSE: 18.1673, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [99/200]
# ----------
# Train Loss: 21.5625, RMSE: 21.4134, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [100/200]
# ----------
# Train Loss: 21.5427, RMSE: 21.3936, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2971, RMSE: 18.1682, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [101/200]
# ----------
# Train Loss: 21.5954, RMSE: 21.4463, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1674, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [102/200]
# ----------
# Train Loss: 21.5199, RMSE: 21.3708, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2970, RMSE: 18.1680, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [103/200]
# ----------
# Train Loss: 21.5791, RMSE: 21.4300, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2964, RMSE: 18.1675, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [104/200]
# ----------
# Train Loss: 21.5218, RMSE: 21.3727, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2964, RMSE: 18.1675, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [105/200]
# ----------
# Train Loss: 21.6103, RMSE: 21.4612, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2968, RMSE: 18.1679, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [106/200]
# ----------
# Train Loss: 21.5483, RMSE: 21.3992, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2959, RMSE: 18.1670, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [107/200]
# ----------
# Train Loss: 21.5839, RMSE: 21.4348, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2970, RMSE: 18.1681, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [108/200]
# ----------
# Train Loss: 21.5777, RMSE: 21.4285, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2968, RMSE: 18.1679, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [109/200]
# ----------
# Train Loss: 21.5404, RMSE: 21.3913, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2958, RMSE: 18.1670, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [110/200]
# ----------
# Train Loss: 21.6127, RMSE: 21.4636, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2954, RMSE: 18.1667, MAPE: 0.1287, Accuracy: 87.13%
# Epoch [111/200]
# ----------
# Train Loss: 21.5966, RMSE: 21.4475, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1674, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [112/200]
# ----------
# Train Loss: 21.5580, RMSE: 21.4088, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2969, RMSE: 18.1680, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [113/200]
# ----------
# Train Loss: 21.5146, RMSE: 21.3655, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [114/200]
# ----------
# Train Loss: 21.5294, RMSE: 21.3802, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2973, RMSE: 18.1682, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [115/200]
# ----------
# Train Loss: 21.5368, RMSE: 21.3877, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2969, RMSE: 18.1680, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [116/200]
# ----------
# Train Loss: 21.6024, RMSE: 21.4533, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2967, RMSE: 18.1679, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [117/200]
# ----------
# Train Loss: 21.5444, RMSE: 21.3954, MAPE: 0.1490, Accuracy: 85.10%
# Val Loss: 18.2963, RMSE: 18.1674, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [118/200]
# ----------
# Train Loss: 21.5463, RMSE: 21.3972, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2976, RMSE: 18.1685, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [119/200]
# ----------
# Train Loss: 21.6089, RMSE: 21.4598, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2970, RMSE: 18.1680, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [120/200]
# ----------
# Train Loss: 21.5526, RMSE: 21.4035, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2970, RMSE: 18.1680, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [121/200]
# ----------
# Train Loss: 21.5805, RMSE: 21.4314, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2964, RMSE: 18.1675, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [122/200]
# ----------
# Train Loss: 21.5349, RMSE: 21.3859, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2958, RMSE: 18.1669, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [123/200]
# ----------
# Train Loss: 21.5467, RMSE: 21.3976, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2969, RMSE: 18.1679, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [124/200]
# ----------
# Train Loss: 21.5310, RMSE: 21.3819, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2971, RMSE: 18.1681, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [125/200]
# ----------
# Train Loss: 21.5521, RMSE: 21.4030, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [126/200]
# ----------
# Train Loss: 21.5901, RMSE: 21.4409, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2980, RMSE: 18.1689, MAPE: 0.1291, Accuracy: 87.09%
# Epoch [127/200]
# ----------
# Train Loss: 21.5193, RMSE: 21.3702, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2968, RMSE: 18.1679, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [128/200]
# ----------
# Train Loss: 21.5679, RMSE: 21.4188, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2960, RMSE: 18.1671, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [129/200]
# ----------
# Train Loss: 21.5785, RMSE: 21.4294, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [130/200]
# ----------
# Train Loss: 21.4805, RMSE: 21.3314, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2972, RMSE: 18.1683, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [131/200]
# ----------
# Train Loss: 21.5575, RMSE: 21.4084, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [132/200]
# ----------
# Train Loss: 21.6046, RMSE: 21.4555, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2960, RMSE: 18.1670, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [133/200]
# ----------
# Train Loss: 21.5077, RMSE: 21.3587, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [134/200]
# ----------
# Train Loss: 21.5660, RMSE: 21.4168, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2977, RMSE: 18.1687, MAPE: 0.1291, Accuracy: 87.09%
# Epoch [135/200]
# ----------
# Train Loss: 21.5411, RMSE: 21.3920, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2978, RMSE: 18.1687, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [136/200]
# ----------
# Train Loss: 21.6240, RMSE: 21.4749, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2967, RMSE: 18.1678, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [137/200]
# ----------
# Train Loss: 21.5738, RMSE: 21.4247, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2967, RMSE: 18.1678, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [138/200]
# ----------
# Train Loss: 21.5621, RMSE: 21.4130, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2967, RMSE: 18.1677, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [139/200]
# ----------
# Train Loss: 21.5897, RMSE: 21.4406, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2960, RMSE: 18.1672, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [140/200]
# ----------
# Train Loss: 21.5218, RMSE: 21.3726, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2979, RMSE: 18.1689, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [141/200]
# ----------
# Train Loss: 21.5901, RMSE: 21.4409, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2969, RMSE: 18.1680, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [142/200]
# ----------
# Train Loss: 21.5454, RMSE: 21.3962, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2985, RMSE: 18.1694, MAPE: 0.1291, Accuracy: 87.09%
# Epoch [143/200]
# ----------
# Train Loss: 21.5445, RMSE: 21.3954, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1674, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [144/200]
# ----------
# Train Loss: 21.5683, RMSE: 21.4192, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [145/200]
# ----------
# Train Loss: 21.5376, RMSE: 21.3885, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2973, RMSE: 18.1683, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [146/200]
# ----------
# Train Loss: 21.5725, RMSE: 21.4235, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2968, RMSE: 18.1678, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [147/200]
# ----------
# Train Loss: 21.5594, RMSE: 21.4102, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1674, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [148/200]
# ----------
# Train Loss: 21.5283, RMSE: 21.3792, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2960, RMSE: 18.1671, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [149/200]
# ----------
# Train Loss: 21.5439, RMSE: 21.3948, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2972, RMSE: 18.1683, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [150/200]
# ----------
# Train Loss: 21.6276, RMSE: 21.4783, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2978, RMSE: 18.1688, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [151/200]
# ----------
# Train Loss: 21.5614, RMSE: 21.4123, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2972, RMSE: 18.1682, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [152/200]
# ----------
# Train Loss: 21.5336, RMSE: 21.3845, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2967, RMSE: 18.1678, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [153/200]
# ----------
# Train Loss: 21.5922, RMSE: 21.4431, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2964, RMSE: 18.1675, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [154/200]
# ----------
# Train Loss: 21.5793, RMSE: 21.4302, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2958, RMSE: 18.1669, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [155/200]
# ----------
# Train Loss: 21.5920, RMSE: 21.4429, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2959, RMSE: 18.1671, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [156/200]
# ----------
# Train Loss: 21.6160, RMSE: 21.4669, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2960, RMSE: 18.1672, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [157/200]
# ----------
# Train Loss: 21.5778, RMSE: 21.4286, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2955, RMSE: 18.1667, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [158/200]
# ----------
# Train Loss: 21.6290, RMSE: 21.4799, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2973, RMSE: 18.1683, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [159/200]
# ----------
# Train Loss: 21.4716, RMSE: 21.3225, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [160/200]
# ----------
# Train Loss: 21.4851, RMSE: 21.3360, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2959, RMSE: 18.1672, MAPE: 0.1287, Accuracy: 87.13%
# Epoch [161/200]
# ----------
# Train Loss: 21.6176, RMSE: 21.4685, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1675, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [162/200]
# ----------
# Train Loss: 21.5919, RMSE: 21.4428, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [163/200]
# ----------
# Train Loss: 21.6121, RMSE: 21.4630, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2964, RMSE: 18.1675, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [164/200]
# ----------
# Train Loss: 21.6142, RMSE: 21.4651, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2971, RMSE: 18.1681, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [165/200]
# ----------
# Train Loss: 21.5557, RMSE: 21.4066, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1675, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [166/200]
# ----------
# Train Loss: 21.5886, RMSE: 21.4395, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1674, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [167/200]
# ----------
# Train Loss: 21.5596, RMSE: 21.4105, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2969, RMSE: 18.1679, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [168/200]
# ----------
# Train Loss: 21.5141, RMSE: 21.3650, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2967, RMSE: 18.1678, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [169/200]
# ----------
# Train Loss: 21.6198, RMSE: 21.4707, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [170/200]
# ----------
# Train Loss: 21.6074, RMSE: 21.4583, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2968, RMSE: 18.1679, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [171/200]
# ----------
# Train Loss: 21.4402, RMSE: 21.2910, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2967, RMSE: 18.1678, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [172/200]
# ----------
# Train Loss: 21.5329, RMSE: 21.3838, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2969, RMSE: 18.1680, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [173/200]
# ----------
# Train Loss: 21.5850, RMSE: 21.4359, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [174/200]
# ----------
# Train Loss: 21.5670, RMSE: 21.4179, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1674, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [175/200]
# ----------
# Train Loss: 21.6005, RMSE: 21.4514, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2964, RMSE: 18.1675, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [176/200]
# ----------
# Train Loss: 21.5406, RMSE: 21.3915, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2977, RMSE: 18.1687, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [177/200]
# ----------
# Train Loss: 21.5857, RMSE: 21.4366, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2970, RMSE: 18.1681, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [178/200]
# ----------
# Train Loss: 21.5574, RMSE: 21.4083, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2974, RMSE: 18.1684, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [179/200]
# ----------
# Train Loss: 21.5469, RMSE: 21.3978, MAPE: 0.1492, Accuracy: 85.08%
# Val Loss: 18.2981, RMSE: 18.1691, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [180/200]
# ----------
# Train Loss: 21.6167, RMSE: 21.4676, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2957, RMSE: 18.1668, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [181/200]
# ----------
# Train Loss: 21.5525, RMSE: 21.4034, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2974, RMSE: 18.1684, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [182/200]
# ----------
# Train Loss: 21.5498, RMSE: 21.4007, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2963, RMSE: 18.1675, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [183/200]
# ----------
# Train Loss: 21.5141, RMSE: 21.3650, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [184/200]
# ----------
# Train Loss: 21.5569, RMSE: 21.4077, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2955, RMSE: 18.1666, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [185/200]
# ----------
# Train Loss: 21.5388, RMSE: 21.3897, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2968, RMSE: 18.1679, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [186/200]
# ----------
# Train Loss: 21.5954, RMSE: 21.4463, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2972, RMSE: 18.1682, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [187/200]
# ----------
# Train Loss: 21.4799, RMSE: 21.3307, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [188/200]
# ----------
# Train Loss: 21.5909, RMSE: 21.4419, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2964, RMSE: 18.1675, MAPE: 0.1288, Accuracy: 87.12%
# Epoch [189/200]
# ----------
# Train Loss: 21.5620, RMSE: 21.4128, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2974, RMSE: 18.1684, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [190/200]
# ----------
# Train Loss: 21.5800, RMSE: 21.4309, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2968, RMSE: 18.1678, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [191/200]
# ----------
# Train Loss: 21.5603, RMSE: 21.4112, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2966, RMSE: 18.1677, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [192/200]
# ----------
# Train Loss: 21.5232, RMSE: 21.3741, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2970, RMSE: 18.1681, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [193/200]
# ----------
# Train Loss: 21.5976, RMSE: 21.4485, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2965, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [194/200]
# ----------
# Train Loss: 21.5099, RMSE: 21.3608, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2968, RMSE: 18.1679, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [195/200]
# ----------
# Train Loss: 21.5758, RMSE: 21.4267, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2969, RMSE: 18.1679, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [196/200]
# ----------
# Train Loss: 21.5735, RMSE: 21.4245, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2967, RMSE: 18.1678, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [197/200]
# ----------
# Train Loss: 21.5825, RMSE: 21.4334, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2973, RMSE: 18.1683, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [198/200]
# ----------
# Train Loss: 21.5579, RMSE: 21.4087, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2973, RMSE: 18.1683, MAPE: 0.1290, Accuracy: 87.10%
# Epoch [199/200]
# ----------
# Train Loss: 21.5795, RMSE: 21.4304, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2964, RMSE: 18.1676, MAPE: 0.1289, Accuracy: 87.11%
# Epoch [200/200]
# ----------
# Train Loss: 21.5861, RMSE: 21.4370, MAPE: 0.1491, Accuracy: 85.09%
# Val Loss: 18.2973, RMSE: 18.1683, MAPE: 0.1290, Accuracy: 87.10%
# Best Train Loss: 21.4402, Best Train RMSE: 21.2910, Best Train MAPE: 0.1465, Best Train Accuracy: 85.35%
# Best Val Loss: 18.2922, Best Val RMSE: 18.1641, Best Val MAPE: 0.1247, Best Val Accuracy: 87.53%
